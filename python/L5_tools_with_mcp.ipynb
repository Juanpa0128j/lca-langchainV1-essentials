# %% [markdown]
# # Tools with MCP ⏰
#
# The Model Context Protocol (MCP) provides a standardized way to connect AI agents to external tools and data sources. Let's connect to an MCP server using `langchain-mcp-adapters`.

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables

# %%
from dotenv import load_dotenv
from env_utils import doublecheck_env

# Load environment variables from .env
load_dotenv()

# Check and print results
doublecheck_env("example.env")
# Out:
# OPENAI_API_KEY=****tM0A
# LANGSMITH_API_KEY=****bc46
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ials

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
import nest_asyncio

nest_asyncio.apply()

# Connect to the mcp-time server for timezone-aware operations
# This Go-based server provides tools for current time, relative time parsing,
# timezone conversion, duration arithmetic, and time comparison
mcp_client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "npx",
            "args": ["-y", "@theo.foobar/mcp-time"],
        }
    },
)

# Load tools from the MCP server
mcp_tools = await mcp_client.get_tools()
print(f"Loaded {len(mcp_tools)} MCP tools: {[t.name for t in mcp_tools]}")
# Out:
# Loaded 5 MCP tools: ['add_time', 'compare_time', 'convert_timezone', 'current_time', 'relative_time']

# %% [markdown]
# Create an agent with the MCP-provided time tools.

# %%
from langchain.agents import create_agent

agent_with_mcp = create_agent(
    model="openai:gpt-5",
    tools=mcp_tools,
    system_prompt="You are a helpful assistant",
)

# %% [markdown]
# Ask about the current time in San Francisco.

# %%
result = await agent_with_mcp.ainvoke(
    {"messages": [{"role": "user", "content": "What's the time in SF right now?"}]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's the time in SF right now?
# ================================== Ai Message ==================================
# Tool Calls:
#   current_time (call_GXdYb86RPKJOXwoem2bzbaHi)
#  Call ID: call_GXdYb86RPKJOXwoem2bzbaHi
#   Args:
#     format: Monday, January 2, 2006 3:04 PM MST
#     timezone: America/Los_Angeles
# ================================= Tool Message =================================
# Name: current_time
#
# Sunday, November 9, 2025 4:18 PM PST
# ================================== Ai Message ==================================
#
# It's Sunday, November 9, 2025, 4:18 PM PST in San Francisco.

# %%
result = await agent_with_mcp.ainvoke(
    {"messages": [{"role": "user", "content": "What's the time in Bello Colombia right now?"}]}
)
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's the time in Bello Colombia right now?
# ================================== Ai Message ==================================
# Tool Calls:
#   current_time (call_ldVcJ6st221gqPflrrMZlJCJ)
#  Call ID: call_ldVcJ6st221gqPflrrMZlJCJ
#   Args:
#     format: Monday, January 2, 2006 3:04:05 PM Z07:00
#     timezone: America/Bogota
# ================================= Tool Message =================================
# Name: current_time
#
# Sunday, November 9, 2025 7:18:53 PM -05:00
# ================================== Ai Message ==================================
#
# Right now in Bello, Colombia (UTC-5), it’s Sunday, November 9, 2025, 7:18:53 PM.
